# %%
from IPython.display import Video
from ui import create_widgets
from data_plt import *
from imports import *
from utils import *

# %%
widget_box = create_widgets()
display(widget_box)

# %%
print(widget_box.children[5].children[1].value)
# Out:
# 30.2

# %%
display(create_plot(widget_box))
Video("animation.mp4", embed=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 display(create_plot(widget_box))
#       2 Video("animation.mp4", embed=True)
#
# File ~\Documents\Files\SkyWatchPro\products\radar\github\data_plt.py:26, in create_plot(widget_box)
#      24 cat = rs.get_catalog(query)
#      25 ds = cat.datasets[0]
# ---> 26 data = ds.remote_access()
#      27 fig = plt.figure(figsize=(10, 7.5))
#      28 ax = new_map(fig, data.StationLongitude, data.StationLatitude)
#
# File ~\.conda\envs\GOES_program\lib\site-packages\siphon\catalog.py:668, in Dataset.remote_access(self, service, use_xarray)
#     665 if service not in (CaseInsensitiveStr('CdmRemote'), CaseInsensitiveStr('OPENDAP')):
#     666     raise ValueError(service + ' is not a valid service for remote_access')
# --> 668 return self.access_with_service(service, use_xarray)
#
# ...
